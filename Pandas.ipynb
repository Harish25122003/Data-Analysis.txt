# %%
import pandas as pd
s = pd.Series()
print(s)
# Out:
# Series([], dtype: float64)
# C:\Users\thaku\AppData\Local\Temp\ipykernel_13660\2600921069.py:2: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.Series()

# %%
import pandas as pd
import numpy as np
list1 = ['a', 'b', 'c', 'd' ]
data = np.array(list1)
s = pd.Series(data)
print("numpy representation of data \n",data,"\n")
print("pandas series representation \n",s,"\n")
# Out:
# numpy representation of data
#  ['a' 'b' 'c' 'd']
#
# pandas series representation
#  0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
import pandas as pd
import numpy as np
list1 = ['a', 'b', 'c', 'd' ]
data = np.array(list1)
s = pd.Series(data,index = [100,101,102,103])
print("numpy representation of data \n",data,"\n")
print("pandas series representation \n",s,"\n")
# Out:
# numpy representation of data
#  ['a' 'b' 'c' 'd']
#
# pandas series representation
#  100    a
# 101    b
# 102    c
# 103    d
# dtype: object

# %%
import pandas as pd
data = {'a' :0., 'b':1. ,"c":2.}
s = pd.Series(data,index = ['b','a','d','e','c'])
print(s)
# Out:
# b    1.0
# a    0.0
# d    NaN
# e    NaN
# c    2.0
# dtype: float64

# %%
import pandas as pd
s = pd.Series(5 , index = [0,1,2,3,8])
print(s)
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 8    5
# dtype: int64

# %%
import pandas as pd
s = pd.Series([1,2,3,4,5], index = ['a','b','c','d','e'])
print(s[:3])
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
import pandas as pd
s = pd.Series([1,2,3,4,5], index = ['a','b','c','d','e'])
print(s[:-3])
import pandas as pd
s = pd.Series([1,2,3,4,5], index = ['a','b','c','d','e'])
print(s[-3:])
# Out:
# a    1
# b    2
# dtype: int64
# c    3
# d    4
# e    5
# dtype: int64

# %%
import pandas as pd
s=pd.Series([1,2,3,4,5], index = ['a','b','c','d','e'])
print(s['a'],s['b'],s['e'])
# Out:
# 1 2 5

# %%
import pandas as pd
s=pd.Series([1,2,3,4,5], index = ['a','b','c','d','e'])
print(s['a'],s['b'],s['e'])
mult1 = s['b'] * s["d"]
print(mult1)
mult1 = s['c'] * s['d'] * s['b']
print(mult1)
div1 = s['e'] / s['b']
print(div1)
# Out:
# 1 2 5
# 8
# 24
# 2.5

# %%
import pandas as pd
data=[["alex",30],["tata",23],["yay",82]]
df = pd.DataFrame(data,columns=['Name','Age'])
print(df)
# Out:
#    Name  Age
# 0  alex   30
# 1  tata   23
# 2   yay   82

# %% [markdown]
# import pandas as pd
# data = {'Name:['Alex', 'daxda','memda'], 'Age':[12,45,23]}
# df = pd.DataFrame(data)
# print(df)

# %%
import pandas as pd
data = {'Name':['Alex', 'shemda','memda'], 'Age':[12,45,23]} 
df = pd.DataFrame(data) 
print(df)
df = pd.DataFrame(data,index=['rank1','rank2','rank3'])
print(df)
# Out:
#      Name  Age
# 0    Alex   12
# 1  shemda   45
# 2   memda   23
#          Name  Age
# rank1    Alex   12
# rank2  shemda   45
# rank3   memda   23

# %%
import pandas as pd
data = [{'a':1,'b':2},{'a':2,'b':4,'c':8},{'a':4,'c':6}]
df1=pd.DataFrame(data)
df2=pd.DataFrame(data,columns=['a','b1','c'])
print(df1)
print(df2)
# Out:
#    a    b    c
# 0  1  2.0  NaN
# 1  2  4.0  8.0
# 2  4  NaN  6.0
#    a  b1    c
# 0  1 NaN  NaN
# 1  2 NaN  8.0
# 2  4 NaN  6.0

# %%
import pandas as pd
d = {'one' : pd.Series([1,2,3], index=['a','b','c']), 'two' : pd.Series([1,2,3,4], index=['a','b','c','d'])}
df=pd.DataFrame(d)
print(df)
print(df['one'])
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4
# a    1.0
# b    2.0
# c    3.0
# d    NaN
# Name: one, dtype: float64

# %%
import pandas as pd
d = {'one' : pd.Series([1,2,3], index=['a','b','c']), 'two' : pd.Series([1,2,3,4], index=['a','b','c','d'])}
df=pd.DataFrame(d)
df['three']=pd.Series([5,6,7], index=['a','b','c'])
print(df)
df['four']=df['one']+df['three']
print(df)
# Out:
#    one  two  three
# a  1.0    1    5.0
# b  2.0    2    6.0
# c  3.0    3    7.0
# d  NaN    4    NaN
#    one  two  three  four
# a  1.0    1    5.0   6.0
# b  2.0    2    6.0   8.0
# c  3.0    3    7.0  10.0
# d  NaN    4    NaN   NaN

# %%
import pandas as pd
d = {'one' : pd.Series([1,2,3], index=['a','b','c']), 'two' : pd.Series([1,2,3,4], index=['a','b','c','d'])}
df=pd.DataFrame(d)
df['three']=pd.Series([5,6,7], index=['a','b','c'])
print(df)
df['four']=df['one']+df['three']
print(df)
#using del function
del df['two']
print("here now second column is deleted")
print(df)
#using pop funstion
df.pop('one')
print("after pop function")
print(df)
# Out:
#    one  two  three
# a  1.0    1    5.0
# b  2.0    2    6.0
# c  3.0    3    7.0
# d  NaN    4    NaN
#    one  two  three  four
# a  1.0    1    5.0   6.0
# b  2.0    2    6.0   8.0
# c  3.0    3    7.0  10.0
# d  NaN    4    NaN   NaN
# here now second column is deleted
#    one  three  four
# a  1.0    5.0   6.0
# b  2.0    6.0   8.0
# c  3.0    7.0  10.0
# d  NaN    NaN   NaN
# after pop function
#    three  four
# a    5.0   6.0
# b    6.0   8.0
# c    7.0  10.0
# d    NaN   NaN
# <Axes: >

# %%
import pandas as pd
d = {'one' : pd.Series([1,2,3], index=['a','b','c']), 'two' : pd.Series([1,2,3,4], index=['a','b','c','d'])}
df=pd.DataFrame(d)
# integer location to iloc function
print(df.loc['b'])
# Out:
# one    2.0
# two    2.0
# Name: b, dtype: float64

# %%
import pandas as pd
df = pd.DataFrame([[1,2],[3,4]],columns=['a','b'])
df2 = pd.DataFrame([[5,6],[7,8]],columns=['a','b'])
df = df.append(df2)
print(df,"\n")
#drop row with label 0
df=df.drop(0)
print(df)
# Out:
#    a  b
# 0  1  2
# 1  3  4
# 0  5  6
# 1  7  8
#
#    a  b
# 1  3  4
# 1  7  8
# C:\Users\thaku\AppData\Local\Temp\ipykernel_8364\1918143419.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(15,5),index=pd.date_range('1/3/2000',periods=15),columns=list('ABCDE'))
print(df)
df.plot()
# Out:
#                    A         B         C         D         E
# 2000-01-03  0.701212 -1.718156  0.226373 -0.911250 -0.189418
# 2000-01-04 -1.032237 -0.236091  1.134793  1.822095  0.772974
# 2000-01-05 -0.277519  0.445179  0.546019 -1.664459  0.287988
# 2000-01-06 -1.768366  2.515410  0.502374  1.335894  0.320916
# 2000-01-07 -0.183247 -1.522799  0.868867 -0.245815  0.643123
# 2000-01-08 -1.140530 -0.724633 -0.146516  0.024568  0.976878
# 2000-01-09  1.193461 -0.443350 -0.857115 -0.978540 -0.986765
# 2000-01-10 -1.541220 -0.325608 -0.598365  0.089328 -0.273237
# 2000-01-11  0.658833  0.371647 -0.955570 -0.644449 -0.268783
# 2000-01-12  1.283038  0.834377  0.247711 -0.828524  0.734887
# 2000-01-13  0.378303  0.743462 -0.627654 -0.412171 -1.320269
# 2000-01-14 -0.370805 -0.486807  0.224041  0.525800 -0.921422
# 2000-01-15  0.433584  0.786669 -1.486242  1.339559 -0.911792
# 2000-01-16  0.211134 -0.197007  1.333963  0.678995 -0.505856
# ...

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(10,2),index=pd.date_range('1/1/2000',periods=10),columns=list(['A','D']))
print(df)
df.plot()
df.plot.bar()
# Out:
#                    A         D
# 2000-01-01 -0.107319  0.242858
# 2000-01-02  0.396738  0.648356
# 2000-01-03 -0.505186  0.235992
# 2000-01-04  0.510885 -0.963124
# 2000-01-05  2.156685 -1.573238
# 2000-01-06 -1.155381 -2.980895
# 2000-01-07  0.398201 -0.308966
# 2000-01-08 -0.272954  2.189664
# 2000-01-09 -0.287513 -0.723278
# 2000-01-10 -1.403079  0.930803
# <Axes: >

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
print(df)
df.plot.bar()
# Out:
#           a         b         c         d
# 0  0.566985  0.897211  0.471010  0.014744
# 1  0.345342  0.223184  0.257335  0.420840
# 2  0.131630  0.795945  0.333551  0.246872
# 3  0.019329  0.854822  0.998904  0.011160
# 4  0.216329  0.648487  0.243807  0.904946
# 5  0.722229  0.071147  0.631629  0.877846
# 6  0.712569  0.319519  0.925692  0.727160
# 7  0.464358  0.564508  0.361985  0.699014
# 8  0.461695  0.786385  0.190471  0.854909
# 9  0.008181  0.782051  0.616739  0.647183
# <Axes: >

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
print(df)
df.plot.bar(stacked=True)
# Out:
#           a         b         c         d
# 0  0.331500  0.754880  0.114082  0.529024
# 1  0.222198  0.664022  0.783949  0.023753
# 2  0.946938  0.865436  0.165145  0.099429
# 3  0.321030  0.699029  0.474089  0.396772
# 4  0.653999  0.064059  0.785536  0.591386
# 5  0.520313  0.858248  0.619744  0.682401
# 6  0.191828  0.055646  0.335806  0.511189
# 7  0.418099  0.218551  0.075784  0.606545
# 8  0.165861  0.844934  0.289901  0.223521
# 9  0.985396  0.011656  0.996275  0.637557
# <Axes: >

# %%
import pandas as pd
d = {'one' : pd.Series([1,2,3], index=['a','b','c']), 'two' : pd.Series([1,2,3,4], index=['a','b','c','d'])}
df=pd.DataFrame(d)
df['three']=pd.Series([5,6,7], index=['a','b','c'])
print(df)
df['four']=df['one']+df['three']
print(df)
df.plot()
df.plot.bar()
df.plot.bar(stacked=True)
# Out:
#    one  two  three
# a  1.0    1    5.0
# b  2.0    2    6.0
# c  3.0    3    7.0
# d  NaN    4    NaN
#    one  two  three  four
# a  1.0    1    5.0   6.0
# b  2.0    2    6.0   8.0
# c  3.0    3    7.0  10.0
# d  NaN    4    NaN   NaN
# <Axes: >

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
print(df)
df.plot.barh(stacked=True)
# Out:
#           a         b         c         d
# 0  0.243143  0.814527  0.273420  0.376082
# 1  0.502076  0.176420  0.354396  0.959672
# 2  0.623726  0.847960  0.805795  0.455242
# 3  0.785817  0.448163  0.227539  0.958181
# 4  0.381396  0.809011  0.349487  0.649323
# 5  0.264506  0.751727  0.920381  0.658229
# 6  0.772062  0.374356  0.427950  0.205644
# 7  0.126690  0.077507  0.276882  0.216027
# 8  0.425224  0.377932  0.648027  0.282530
# 9  0.329394  0.123917  0.727409  0.756020
# <Axes: >

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({'a':np.random.randn(1000)+1,'b':np.random.randn(1000),'c':np.random.randn(1000)-1}, columns=['a','b','c'])
print(df)
df.plot.hist(bins=20)
# Out:
#             a         b         c
# 0   -0.097950  0.615602 -0.840468
# 1   -0.452288  0.179126  0.679764
# 2    1.333256  0.006614 -1.691407
# 3    0.292757 -1.610334 -1.592981
# 4    0.629579  0.538880 -1.869027
# ..        ...       ...       ...
# 995  0.445895  1.260946 -0.763757
# 996  0.043218 -1.055434 -0.670247
# 997  0.978746 -1.437778 -0.657706
# 998  2.201658  1.485407 -3.097024
# 999  2.360418  1.651685  0.289981
#
# [1000 rows x 3 columns]
# <Axes: ylabel='Frequency'>

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({'a':np.random.rand(1000)+1,'b':np.random.rand(1000),'c':np.random.rand(1000)-1}, columns=['a','b','c'])
print(df)
df.plot.hist(bins=20)
df.plot.hist(bins=200)
df.plot.hist(bins=2000)
# Out:
#             a         b         c
# 0    1.077837  0.310830 -0.050142
# 1    1.097806  0.155277 -0.102279
# 2    1.034043  0.953720 -0.661577
# 3    1.779928  0.974968 -0.616407
# 4    1.570725  0.962183 -0.318499
# ..        ...       ...       ...
# 995  1.782591  0.849708 -0.903939
# 996  1.128848  0.513236 -0.099202
# 997  1.399618  0.081907 -0.824236
# 998  1.311470  0.960337 -0.173127
# 999  1.026374  0.125289 -0.643670
#
# [1000 rows x 3 columns]
# <Axes: ylabel='Frequency'>

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({'a':np.random.rand(1000)+1,'b':np.random.rand(1000),'c':np.random.rand(1000)-1}, columns=['a','b','c'])
print(df)
df.plot.hist(bins=20000)
# Out:
#             a         b         c
# 0    1.741309  0.877193 -0.149701
# 1    1.018677  0.039724 -0.993101
# 2    1.617271  0.912295 -0.753835
# 3    1.092160  0.265480 -0.962816
# 4    1.534317  0.319111 -0.571388
# ..        ...       ...       ...
# 995  1.137047  0.273630 -0.168342
# 996  1.575496  0.472256 -0.784281
# 997  1.140906  0.716095 -0.618895
# 998  1.282996  0.624848 -0.487964
# 999  1.706783  0.848577 -0.118716
#
# [1000 rows x 3 columns]
# <Axes: ylabel='Frequency'>

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(10,4), columns=['a','b','c','d'])
print(df)
df.plot.box()
# Out:
#           a         b         c         d
# 0 -0.703705 -0.866420  0.907554  1.151959
# 1 -0.354497  1.471372  0.300112  0.349628
# 2 -2.394707 -1.033156 -0.317656 -0.546980
# 3  0.170532 -0.603740  0.907443 -0.717543
# 4 -0.891209 -1.764892  0.687584 -0.548040
# 5  0.504477 -0.417142  0.517475 -0.845063
# 6  0.303012 -0.122427 -0.593667 -1.123149
# 7  0.226228 -0.631510 -0.536711  0.202978
# 8 -0.013090  0.726570  1.049830 -0.203490
# 9 -0.844701 -1.181569 -0.520587 -0.317316
# <Axes: >

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(10,4), columns=['a','b','c','d'])
print(df)
df.plot.area()
# Out:
#           a         b         c         d
# 0  0.242093  0.135750  0.458625  0.733241
# 1  0.052777  0.223568  0.789914  0.348183
# 2  0.447292  0.547870  0.850126  0.894971
# 3  0.844973  0.592482  0.586935  0.382039
# 4  0.914684  0.796308  0.539543  0.524549
# 5  0.890252  0.383446  0.807956  0.353836
# 6  0.631279  0.357932  0.394863  0.204502
# 7  0.709061  0.846054  0.751431  0.225277
# 8  0.824527  0.971066  0.319075  0.509411
# 9  0.815644  0.315416  0.552035  0.423368
# <Axes: >

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(40,4), columns=['a','b','c','d'])
print(df)
df.plot.scatter(x='a',y='b')
# Out:
#            a         b         c         d
# 0   0.697065  0.141311  0.473495  0.891174
# 1   0.956422  0.181085  0.895559  0.482674
# 2   0.075208  0.955990  0.067245  0.471031
# 3   0.706084  0.165006  0.511235  0.766267
# 4   0.247625  0.814889  0.051950  0.895663
# 5   0.319545  0.764224  0.996592  0.889692
# 6   0.659683  0.213346  0.054992  0.938962
# 7   0.371397  0.039373  0.930664  0.923691
# 8   0.041017  0.390567  0.294147  0.714596
# 9   0.876555  0.821872  0.693783  0.765005
# 10  0.735131  0.946706  0.685732  0.200593
# 11  0.506802  0.579780  0.479168  0.328982
# 12  0.389586  0.414855  0.628808  0.535575
# 13  0.235831  0.726632  0.256941  0.324655
# 14  0.022588  0.889626  0.657421  0.092559
# 15  0.278053  0.577721  0.651938  0.264790
# 16  0.905299  0.355155  0.353603  0.091353
# 17  0.014739  0.964952  0.569725  0.236665
# 18  0.068176  0.361641  0.983906  0.281988
# 19  0.302338  0.080774  0.392648  0.154008
# 20  0.734765  0.335714  0.972985  0.961335
# ...

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(3*np.random.rand(4), index=['a','b','c','d'],columns=['x'])
print(df)
df.plot.pie(subplots=True)
# Out:
#           x
# a  1.484572
# b  0.965363
# c  1.341888
# d  0.181310
# array([<Axes: ylabel='x'>], dtype=object)
